# %% [markdown]
# ### Netfllix Dataset about TV shows and Movies availble on Netflix till 2021

# %%
# Library Import
import pandas as pd 

# importing the data frame 
df = pd.read_csv(r'C:\Users\NONSO\Desktop\Python for Data Analysis\DataSets\Netflix Data.csv')

# %%
df     #lets have a view of the dataframe
# Out:
#      Show_Id Category                                        Title  \
# 0         s1  TV Show                                           3%
# 1         s2    Movie                                        07:19
# 2         s3    Movie                                        23:59
# 3         s4    Movie                                            9
# 4         s5    Movie                                           21
# 5         s6  TV Show                                           46
# 6         s7    Movie                                          122
# 7         s8    Movie                                          187
# 8         s9    Movie                                          706
# 9        s10    Movie                                         1920
# 10       s11    Movie                                         1922
# 11       s12  TV Show                                         1983
# 12       s13  TV Show                                         1994
# ...

# %%
df.head()     #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()       #returns the last 5 rows of the DataFrame by default.
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape      # to show the number of rows and columns
# Out:
# (7789, 11)

# %%
df.columns      # to show each column name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.size           # to show the total number of elements in the dataset
# Out:
# 85679

# %%
df.dtypes         # to show the datatype of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()  # to show indexes, columns and data types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
# Show_Id         7789 non-null object
# Category        7789 non-null object
# Title           7789 non-null object
# Director        5401 non-null object
# Cast            7071 non-null object
# Country         7282 non-null object
# Release_Date    7779 non-null object
# Rating          7782 non-null object
# Duration        7789 non-null object
# Type            7789 non-null object
# Description     7789 non-null object
# dtypes: object(11)
# memory usage: 669.4+ KB

# %% [markdown]
# <h4> Checking for Duplicates

# %%
df.head()      #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape      # get the dimensions(rows, columns) of a DataFrame
# Out:
# (7789, 11)

# %%
df.duplicated()        # to check for duplicate values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 7759    False
# 7760    False
# 7761    False
# 7762    False
# 7763    False
# 7764    False
# 7765    False
# 7766    False
# 7767    False
# 7768    False
# 7769    False
# 7770    False
# 7771    False
# 7772    False
# 7773    False
# 7774    False
# 7775    False
# 7776    False
# 7777    False
# 7778    False
# 7779    False
# 7780    False
# 7781    False
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# ...

# %%
df[df.duplicated()]      # to check row-wise for duplicate rows
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)  # lets drop the duplicate rows

# %%
df[df.duplicated()] # we did this again to ensure that the duplicates hve been removed
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.shape        # get the dimensions(rows, columns) of a DataFrame
# Out:
# (7787, 11)

# %% [markdown]
# <h4> lets check for Null Values

# %%
df.head()      #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.isnull()      # to show where null values are present
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# 5       False     False  False     False  False    False         False
# 6       False     False  False     False  False    False         False
# 7       False     False  False     False  False    False         False
# 8       False     False  False     False  False    False         False
# 9       False     False  False     False  False    False         False
# 10      False     False  False     False  False    False         False
# 11      False     False  False      True  False    False         False
# ...

# %%
 df.isnull().sum()    # to check the count of null values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# <h4> Heat map showing null values count <h4>

# %%
# lets import seaborn
import seaborn as sns

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# <h4> For "House of Cards",  what is the Show ID and who is the Director?

# %%
df.head()      #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df[df['Title'].isin(["House of Cards"])]         

# to show thd records of a particular item in any column 
# using "isin()" to solve it
#returns the first 5 rows of the DataFrame by default.
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# using "str.contains()" to solve it

df[df["Title"].str.contains("House of Cards")]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# <h4> In which year highest number of the TV Shows & Movies were released? Show with  bar chat

# %%
df.dtypes    # lets check for data types
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# lets create "Date_N" a new column
# also we will use "to_date()" function
df['Date_N'] = pd.to_datetime(df['Release_Date'])

# %%
df.head()      # to confirm if the column has been created
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.dtypes       #to check our data types
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
# now lets check for the year in which the highest number of TV shows or Movies were released
# and we will do that using "dt.year.value_counts()"

df['Date_N'].dt.year.value_counts()          # it counts the occurence of all individual years in the date column
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
# for the bar graph

df['Date_N'].dt.year.value_counts().plot(kind='bar')

# %% [markdown]
# <h4> How many Movies & TV Shows are in the dataset? Show with a Bar Graph

# %%
df.head()      #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# using the ".groupby()" and ".count()" we will get the number of  movies and Tv Shows
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
df.groupby('Category').Category.count().plot(kind='bar')    # showing on a bar chart

# %%
# we can also use the ".countplot()"

sns.countplot(df['Category'])        #to show the count of all unique values of any column in the form of bar graph

# %% [markdown]
# <H4> Show all the Movies that were released in the year 2000

# %%
df.head()         #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# lets create a new colum from "Date_N" column 

df['Year'] = df['Date_N'].dt.year

# %%
df.head(3)      # lets confirm if the new column has been creted
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %%
# to get all the movies released in 2000, we will apply filtering 
df[(df['Category'] =='Movie') & (df['Year'] == 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
# Lets check for the tv shows released in 2000

df[(df['Category']=='TV Show') & (df['Year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
# to get all the Movies released in the year 2020
df[(df['Category']=='Movie')  &  (df['Year']==2020)]
# Out:
#      Show_Id Category                                              Title  \
# 4         s5    Movie                                                 21
# 6         s7    Movie                                                122
# 14       s15    Movie                                               3022
# 27       s28    Movie                                             #Alive
# 28       s29    Movie                      #AnneFrank - Parallel Stories
# 30       s31    Movie                                   #cats_the_mewvie
# 31       s32    Movie                                  #FriendButMarried
# 32       s33    Movie                                #FriendButMarried 2
# 43       s44    Movie                                            Òlòtūré
# 73       s74    Movie                                        18 Presents
# 75       s76    Movie                                                1BR
# 77       s78    Movie                                   2 Alone in Paris
# ...

# %%
# to get all the TV Shows released in the year 2020
df[(df['Category']=='TV Shows')  &  (df['Year']==2020)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# <H4> Show only all the titles of all TV Shows released in India only

# %%
df.head(4)   #returns the first 4 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# ...

# %%
# to show all the TV shows released in india
# this was done using "filtering" method

df[(df['Category']=='TV Show') & (df['Country']=='India')]['Title']
# Out:
# 86                       21 Sarfarosh: Saragarhi 1897
# 132                                         7 (Seven)
# 340                                      Agent Raghav
# 364                                      Akbar Birbal
# 533                               Anjaan: Rural Myths
# 534                       Anjaan: Special Crimes Unit
# 686                       Bad Boy Billionaires: India
# 698                        Badalte Rishton Ki Dastaan
# 750                                     Bard of Blood
# 856                                            Betaal
# 879                                       Bh Se Bhade
# 880                                Bhaag Beanie Bhaag
# 881                                    Bhaage Re Mann
# 1316                                     Chhota Bheem
# 1377    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1412                                  Classic Legends
# 1463                                  College Romance
# ...

# %%
# to show all the TV shows released in United States
# this was done using "filtering" method

df[(df['Category']=='TV Show') & (df['Country']=='United States') & (df['Year']==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 26       s27  TV Show                                 (Un)Well
# 29       s30  TV Show                                 #blackAF
# 53       s54  TV Show                               100 Humans
# 63       s64  TV Show                           13 Reasons Why
# 130     s131  TV Show                               60 Days In
# 195     s196  TV Show                      A Lion in the House
# 289     s290  TV Show                            Absurd Planet
# 357     s358  TV Show                         AJ and the Queen
# 380     s381  TV Show                            Alexa & Katie
# 405     s406  TV Show                             All American
# 437     s438  TV Show                           Altered Carbon
# 452     s453  TV Show                 America's Next Top Model
# 468     s469  TV Show                    American Horror Story
# 574     s575  TV Show                          Are You The One
# ...

# %% [markdown]
# <h4> Show top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix?

# %%
df.head()       #returns the first 5 rows of the DataFrame by default.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#we will use the "value_counts()" to answer the question
#we also used '.head(10)' to show the top 10
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: Director, dtype: int64

# %% [markdown]
# <h4> Show all records , where "Category is Movie and Type is Comedies" OR "Country is united Kingdom".

# %%
df.head(2)  #returns the first 2 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df['Type'].head(10)    #returns the first 10 rows of the column"Type" by default.
# Out:
# 0    International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                         Dramas, International Movies
# 2                  Horror Movies, International Movies
# 3    Action & Adventure, Independent Movies, Sci-Fi...
# 4                                               Dramas
# 5      International TV Shows, TV Dramas, TV Mysteries
# 6                  Horror Movies, International Movies
# 7                                               Dramas
# 8                  Horror Movies, International Movies
# 9       Horror Movies, International Movies, Thrillers
# Name: Type, dtype: object

# %%
df[(df['Category']=='Movie')  & (df['Type']=='Comedies')]   # Category is Movie and Type is Comedies" by filtering
# Out:
#      Show_Id Category                                              Title  \
# 33       s34    Movie                                       #realityhigh
# 72       s73    Movie                                           17 Again
# 84       s85    Movie                                          21 & Over
# 148     s149    Movie                               A Bad Moms Christmas
# 174     s175    Movie                        A Futile and Stupid Gesture
# 240     s241    Movie                                   A Thousand Words
# 317     s318    Movie                        Adventures in Public School
# 472     s473    Movie                       American Pie 9: Girls' Rules
# 522     s523    Movie                                   Anger Management
# 626     s627    Movie        Austin Powers: International Man of Mystery
# 692     s693    Movie                                     Bad Grandpa .5
# 795     s796    Movie                                        Bebe's Kids
# ...

# %%
df[(df['Category']=='Movie')  & (df['Type']=='Comedies') | (df['Country']=='United Kingdom')]

#"Category is Movie and Type is Comedies" OR "Country is united Kingdom"
# Out:
#      Show_Id Category                                        Title  \
# 19       s20    Movie                                          '89
# 33       s34    Movie                                 #realityhigh
# 58       s59  TV Show                                  100% Hotter
# 72       s73    Movie                                     17 Again
# 82       s83    Movie                          2036 Origin Unknown
# 84       s85    Movie                                    21 & Over
# 85       s86  TV Show                                     21 Again
# 93       s94    Movie                            27: Gone Too Soon
# 148     s149    Movie                         A Bad Moms Christmas
# 174     s175    Movie                  A Futile and Stupid Gesture
# 181     s182    Movie       A Grand Night In: The Story of Aardman
# 196     s197    Movie                               A Little Chaos
# 212     s213    Movie                               A Patch of Fog
# ...

# %% [markdown]
# <h4> In how many Movies/Shows was "Tom Cruise" cast?

# %%
df.head(3)     #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %%
df[(df["Cast"]=="Tom Cruise")]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
# sincee we are getting zero result for "Tom Cruise", then we will work on droping the null values with "dropna" and also crete a new data frame "df_new"

df_new = df.dropna()               # it drops the rows that have null or missing values 
# also "df_new is a new dta frame created to solve this"

# %%
df_new.head(3)       #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description     Date_N    Year
# ...

# %%
#now lets get to know how many Movies/Tv shows was "Tom Cruise" casted 
df_new[df_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# <h4> What are the different Ratings defined by Netflix?

# %%
df.head(3)     #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %%
df['Rating'].nunique()        # with "nunique()" we will know total number of ratings availble
# Out:
# 14

# %%
df.Rating.unique()           # with "unique()", it will list all the available ratings

# NB: "df['Rating']" is same as "df.Rating"
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# <h4> How many movies got rating "TV-14" in Canada?

# %%
df.head(3)    #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %%
df[(df['Category']=='Movie') & (df['Rating']=="TV-14") & (df['Country']=='Canada')]    #How many movies got rating "TV-14" in Canada
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
#with ".shape", we can see how many times it occurred
df[(df['Category']=='Movie') & (df['Rating']=="TV-14") & (df['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# <h4> How many TV Shows got "R" Rating, after year 2018?

# %%
df.head(3)        #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year'] > 2018)] #How many TV Shows got "R" Rating, after year 2018
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
# with the '.shape' we can see how many times it occured 
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['Year'] > 2018)].shape
# Out:
# (1, 13)

# %% [markdown]
# <h4> what is the maximum duration of a Movie/Tv show ?

# %%
df.head(3)      #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# ...

# %%
df['Duration'].unique()     # lets see all the unique duration types in it
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
# lets check for data type
df.Duration.dtype
# Out:
# dtype('O')

# %%
# we will be creting two new column "Minute" & "Unit" from "duration"column 
# we will be using ".str.split() functiom" for it

df[['Minute', 'Unit']] = df['Duration'].str.split(' ', expand = True)

# %%
df.head()       # used this confirm if we suucessfully splited "minute " and "unit"
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# now lets get the maximum duration of a TV show/Movie
# We will be using the ".max()" function and alos the "Minute" Column 

df.Minute.max()
# Out:
# '99'

# %% [markdown]
# <h4> Which country has the highest number of TV shows

# %%
df.head(2)     #returns the first 2 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
#Lets create a new data frame"TV Shows" from "category" column

df_TVShow = df[df['Category'] == 'TV Show']

# %%
# lets view the new data frame 
df_TVShow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minute     Unit
# 0      4  Seasons
# 5      1   Season

# %%
#now lets see the countries with their  number of TV shows
df_TVShow['Country'].value_counts()
# Out:
# United States                                                  705
# United Kingdom                                                 204
# Japan                                                          157
# South Korea                                                    147
# India                                                           71
# Taiwan                                                          68
# Canada                                                          59
# France                                                          46
# Australia                                                       46
# Spain                                                           45
# China                                                           36
# Mexico                                                          35
# Turkey                                                          27
# Brazil                                                          26
# ...

# %%
#now lets see the country with highest number of TV shows
# '.value_counts()' gives total count of each country 
#".head(1)" is used to show only the top1
df_TVShow['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %%
#now lets see the top 10 countries with highest number of TV Shows
df_TVShow['Country'].value_counts().head(10)
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Taiwan             68
# Canada             59
# France             46
# Australia          46
# Spain              45
# Name: Country, dtype: int64

# %% [markdown]
# <h4> How can we sort the dataset by year?

# %%
df.head(3)     #returns the first 3 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_N    Year  \
# ...

# %%
# this will be done with ".sort_values"

df.sort_values(by = 'Year')
# Out:
#      Show_Id Category                                        Title  \
# 7115   s7114    Movie                         To and From New York
# 1765   s1766  TV Show                              Dinner for Five
# 3248   s3249    Movie                      Just Another Love Story
# 5766   s5766    Movie                                     Splatter
# 3840   s3841    Movie                  Mad Ron's Prevues from Hell
# 6847   s6846    Movie                         The Ryan White Story
# 308     s309    Movie                     Adam: His Song Continues
# 7416   s7415    Movie                             Victim of Beauty
# 7232   s7231    Movie                         Triumph of the Heart
# 7364   s7363    Movie                             Unspeakable Acts
# 232     s233    Movie                   A Stoning in Fulham County
# 2962   s2963    Movie                  In Defense of a Married Man
# 2622   s2623    Movie                                 Hard Lessons
# ...

# %%
# to show the top 1 using ".head(1)"

df.sort_values(by = 'Year').head(1)
# Out:
#      Show_Id Category                 Title              Director  \
# 7115   s7114    Movie  To and From New York  Sorin Dan Mihalcescu
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
#
#          Release_Date Rating Duration                                   Type  \
# 7115  January 1, 2008  TV-MA   81 min  Dramas, Independent Movies, Thrillers
#
#                                             Description     Date_N    Year  \
# 7115  While covering a story in New York City, a Sea... 2008-01-01  2008.0
#
#      Minute Unit
# 7115     81  min

# %%
# to show the top 5 in descending order

df.sort_values(by = 'Year', ascending=False).head(5)
# Out:
#      Show_Id Category             Title                 Director  \
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country      Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia   January 1, 2021
# 5919                                      United States   January 1, 2021
# ...

# %% [markdown]
# <h4> Find the instances where:
#
#
# <h4>a) Category is 'Movie' and Type is "Drama"
#
# <h4> OR
#
# <H4>b) Category is "TV Show" and Type Is "Kids TV"

# %%
df.head(2)   #returns the first 2 rows of the DataFrame
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
#Category is 'Movie' and Type is "Drama"

df[(df['Category']=="Movie") & (df['Type']=='Dramas')]
# Out:
#      Show_Id Category                            Title  \
# 4         s5    Movie                               21
# 7         s8    Movie                              187
# 170     s171    Movie                     A Family Man
# 232     s233    Movie       A Stoning in Fulham County
# 295     s296    Movie               Across Grace Alley
# 308     s309    Movie         Adam: His Song Continues
# 330     s331    Movie                        Aftermath
# 334     s335    Movie   Agatha and the Truth of Murder
# 422     s423    Movie                 All Together Now
# 429     s430    Movie                  Alone in Berlin
# 455     s456    Movie                  American Beauty
# 466     s467    Movie               American History X
# 474     s475    Movie                     American Son
# 476     s477    Movie              American Warfighter
# 613     s614    Movie          Atlas Shrugged: Part II
# 701     s702    Movie                          Badland
# ...

# %%
#Category is "TV Show" and Type Is "Kids TV"
df[(df['Category']=="TV Show") & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                                              Title  \
# 111     s112  TV Show                                            44 Cats
# 276     s277  TV Show                                       Abby Hatcher
# 434     s435  TV Show                                        Alphablocks
# 598     s599  TV Show                                  Ask the StoryBots
# 706     s707  TV Show                                         Bal Ganesh
# 735     s736  TV Show                       Barbie Dreamhouse Adventures
# 736     s737  TV Show      Barbie Dreamhouse Adventures: Go Team Roberts
# 760     s761  TV Show                                            Bat Pat
# 779     s780  TV Show                                        Be-Be-Bears
# 786     s787  TV Show                                          Beat Bugs
# 828     s829  TV Show                       Ben & Holly's Little Kingdom
# 829     s830  TV Show                                             Ben 10
# ...

# %%
#Category is 'Movie' and Type is "Drama" OR  Category is "TV Show" and Type Is "Kids TV"

df[(df['Category']=="Movie") & (df['Type']=='Dramas') | (df['Category']=="TV Show") & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                                          Title  \
# 4         s5    Movie                                             21
# 7         s8    Movie                                            187
# 111     s112  TV Show                                        44 Cats
# 170     s171    Movie                                   A Family Man
# 232     s233    Movie                     A Stoning in Fulham County
# 276     s277  TV Show                                   Abby Hatcher
# 295     s296    Movie                             Across Grace Alley
# 308     s309    Movie                       Adam: His Song Continues
# 330     s331    Movie                                      Aftermath
# 334     s335    Movie                 Agatha and the Truth of Murder
# 422     s423    Movie                               All Together Now
# 429     s430    Movie                                Alone in Berlin
# 434     s435  TV Show                                    Alphablocks
# ...

# %% [markdown]
# ### THANK YOU.
